# %% [markdown]
# <a href="https://colab.research.google.com/github/Shreenathtech/HackerShreenath/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hi Shreenath")
# Out:
# Hi Shreenath
